# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yh):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - yh) ** 2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 189.848
# The Mean absolute error is 11.457

# %% [markdown]
# HW1:
# 1. 你選的這組資料為何重要
#
# Ans: 我選的挑戰是 -- Store Item Demand Forecasting Challenge
#      我覺得這組資料重要是因為，如果我們能夠精確的預測在什麼時間點，哪一家店的某個商品的販賣量，我們就能避免不必要的浪費，讓供應商知道生產多      少的量是最符合經濟效益，讓整個產業生態鏈可以永續經營，也可以避免惡性的降價競爭。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# Ans: 資料來源是來自該店的歷史數據，該店提供其五年，50件不同商品，10家不同店的銷售狀況。
#
# 3. 蒐集而來的資料型態為何
#
# Ans: 資料型態為單純結構化資料: 數值表格。
#
# 4. 這組資料想解決的問題如何評估
#
# Ans: 透過回歸模型評估我們的預測的誤差值。

# %% [markdown]
# HW2:
#     想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Ans: 業績 = 載客幾趟 * 一趟多少錢
#      如果要提高業績，就是要提高載客的趟數或是每趟的價錢，或是兩者同時增加。但載客趟數有可能會同時影響每趟的價錢，每趟越快，載客趟數就可能可以提高，但相對地，單趟價錢也有可能減少，所以需要評估如果多安排長程載客的趟數，是否會優於都專攻短程載客服務，抑或是兩者該如何分配以達業績最大化。
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# Ans: 時段、地區、送達客人的時間長短、客人本身預期的旅程時間、服務品質、費率等資料都有可能影響問的問題。
#      資料可以從跳表機、google map的定位圖、客人的問卷回饋去做蒐集。
#
# 3. 蒐集而來的資料型態為何
#
# Ans: 會有結構化的資料，如: 數值、時間、距離長短等。以及非結構化的資料，如: 客人的意見回饋、google map的路線圖等。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# Ans: 利用回歸模型去驗證各種參數調整下的所產生預測及其誤差範圍。
